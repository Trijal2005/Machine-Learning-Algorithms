# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score

# %%
data=pd.read_csv("data.csv");
X=data.iloc[:,0]
Y=data.iloc[:,1]
plt.scatter(X,Y)
plt.show()
data.head()
# Out:
#    32.502345269453031  31.70700584656992
# 0           53.426804          68.777596
# 1           61.530358          62.562382
# 2           47.475640          71.546632
# 3           59.813208          87.230925
# 4           55.142188          78.211518

# %%
X = np.array(X).reshape(-1,1)
y = np.array(Y).reshape(-1,1)
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2)

# %%
Lmodel=LinearRegression()
Lmodel.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=Lmodel.predict(x_test)

# %%
plt.scatter(X,Y)
plt.plot([min(X),max(X)],[min(y_pred),max(y_pred)],color='red',label='BEST FIT LINE')
plt.legend()
plt.show()

# %%
print(f"Accuracy:{r2_score(y_test,y_pred)*100}%")
print(f"Accuray:{Lmodel.score(x_test,y_test)*100}%")
# Out:
# Accuracy:62.00913555083736%
# Accuray:62.00913555083736%

# %%
mse=mean_squared_error(y_test,y_pred)
print(f"MSE:{mse}")
# Out:
# MSE:94.31072001734113
